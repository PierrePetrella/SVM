# %% [markdown]
# # Support Vector Machine Lab

# %% [markdown]
# ## 1    Objectives

# %% [markdown]
# ### Question 1:
# Use make_blobsand make_circles from thedatasetslibrary to generate three syntheticnon separable datasets:  2-class and 3-class with blob ”structure” and 2-class with circle structure.  Visualisethe generated data points.  You may need thematplolib.pyplotlibrary and itsscatterfunction.

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs, make_circles 
import sklearn.svm as svm
from sklearn.model_selection import train_test_split

# %%
blobs, blobs_label = make_blobs(n_samples = 100, centers = 2)
circles, circles_label = make_circles(n_samples = 100)

# %%
len(blobs)
# Out:
# 100

# %%
plt.figure(1)
plt.scatter(blobs[:,0],blobs[:,1],c=blobs_label)
plt.figure(2)
plt.scatter(circles[:,0],circles[:,1],c=circles_label)

# %%
X = blobs
y = blobs_label
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
